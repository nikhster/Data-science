# %% [markdown]
# ## Application Programming Interfaces(APIs) - II

# %%
import requests
from requests.auth import HTTPBasicAuth
a = requests.get("https://api.github.com/user",auth=HTTPBasicAuth("Nikhstered","samplegit7"))
print(a.url)
# Out:
# https://api.github.com/user

# %%
#Fetch the license used in ‘google/go-cloud’ Github repository from Github API using basic auth i.e by passing username and password
#Print the license name.
#Note:Read the Github API documentation carefully.
import json
import requests
from requests.auth import HTTPBasicAuth
Response = requests.get("https://api.github.com/repos/google/go-cloud",auth=("Nikhstered","samplegit7"))
pythonData = Response.json()
print( pythonData['license']['name'])
# Out:
# https://api.github.com/repos/google/go-cloud
# Apache License 2.0

# %%
#Fetch the list of topics that are present in ‘google/clusterfuzz’ Github repository from Github API using basic auth i.e by passing username and password.
#Print the topic names
#Note:Read the Github API documentation carefully.
import json
import requests
from requests.auth import HTTPBasicAuth
Response = requests.get("https://api.github.com/repos/google/clusterfuzz/topics",auth=("Nikhstered","samplegit7"), headers = header)
print(Response.status_code)
print(Response.url)
pythonData = json.loads(Response.text)
print(pythonData["names"])
# Out:
# 200
# https://api.github.com/repos/google/clusterfuzz/topics
# ['fuzzing', 'security', 'stability', 'vulnerabilities']

# %%
#ta code
import json
import requests
from requests.auth import HTTPBasicAuth

header={"Accept": "application/vnd.github.mercy-preview+json"}
Response = requests.get("https://api.github.com/repos/google/clusterfuzz/topics",auth=("Nikhstered","samplegit7"), headers = header)

pythonData = Response.json().get('names')
for i in pythonData:
    print(i)
# Out:
# fuzzing
# security
# stability
# vulnerabilities

# %%
#Fetch the list of languages used in ‘google/science-journal-ios’ Github repository from Github API using basic auth i.e by passing username and password.
#Print the language name.
#Note:Read the Github API documentation carefully.


import json
import requests
from requests.auth import HTTPBasicAuth
Response = requests.get("https://api.github.com/repos/google/science-journal-ios",auth=("Nikhstered","samplegit7"))
#print(Response.status_code)
#print(Response.url)
pythonData=json.loads(Response.text)
#pythonData["languages_url"]
Response2 = requests.get("https://api.github.com/repos/googlearchive/science-journal-ios/languages")
pythonData2 = json.loads(Response2.text)
for i in pythonData2.keys():
    print(i)
# Out:
# Swift
# HTML
# Python
# Ruby
# Shell

# %%
#ta code
import requests
import json
from requests.auth import HTTPBasicAuth

a=requests.get("https://api.github.com/repos/google/science-journal-ios/languages",auth=('saachitalwar06@gmail.com','monu1972@T'),headers={"Accept": "application/vnd.github.mercy-preview+json"})
b=json.loads(a.text)
for i in b:
    print(i)

# %% [markdown]
# ## How to get REDDIT access token
# #### Reddit API Documentation - https://www.reddit.com/dev/api/oauth
# #### Steps to generate access token - https://github.com/reddit-archive/reddit/wiki/OAuth2

# %%
# Client ID - WwA-KYZlHOJ1Xw
# Client Secret - BTbg_dgc3q8IVPDEIGMLJY49ZaEEVQ
import requests
import json
data = {"client_id":"WwA-KYZlHOJ1Xw","response_type":"code","state":"random123"
        ,"redirect_uri":"https://www.google.co.in/","scope":"read"}
Response = requests.get("https://www.reddit.com/api/v1/authorize?",params=data)
print(Response.url)
# Out:
# https://www.reddit.com/login/?dest=https%3A%2F%2Fwww.reddit.com%2Fapi%2Fv1%2Fauthorize%3Fclient_id%3DWwA-KYZlHOJ1Xw%26response_type%3Dcode%26state%3Drandom123%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.co.in%252F%26scope%3Dread

# %%
# code = fEmtDCVDFERD9EwChz0-g1zKzKJXtg#_
data = {"grant_type":"authorization_code","code":"fEmtDCVDFERD9EwChz0-g1zKzKJXtg#_","redirect_uri":"https://www.google.co.in/"}
r = requests.post("https://www.reddit.com/api/v1/access_token", data = data, 
                auth = ("WwA-KYZlHOJ1Xw","BTbg_dgc3q8IVPDEIGMLJY49ZaEEVQ"),headers={"User-Agent":"Abhishek"})
print(r.text)
# Out:
# {"error": "invalid_grant"}

# %% [markdown]
# #### Reddit post requests not available now

# %% [markdown]
# ## Assignments

# %%
# github organisation repo
# Fetch the all repositories(except Forked repository) of organisation ‘CodingNinjasCodes’ from Github API using OAuth(access token)
# Print the name of repository with its watch count and fork count.
# Github personal access token = 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
# Client ID - 0240771738a9eb4f676f
# Client secrets - d5fa7881cfbfa2011b88cc515b3b06913b0b4066
import requests
import json
token = "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"
headers = {"Authorisation":"token"+token}
params = {"type":"sources"}
response = requests.get("https://api.github.com/orgs/CodingNinjasCodes/repos",headers = headers, params = params)
pData = response.json()

for i in pData:
    print(i.get("name"),i.get("watchers_count"),i.get("forks_count"))
# Out:
# SmoothScrollJs 16 5
# RubyTutorial 14 9
# Python3Tutorial 5 3
# HTMLandCssNotes 14 24
# Beacathon 2 8
# JSNotes 5 7
# learnml 1 0
# RubyNotebook 2 5
# InterQues 72 160
# coderoom 4 3

# %%
# ta code
import requests
token= '0e868abb4fd92c4d724f1f5be8a7fe0a3da43642'
headers = {'Authorization' : 'token' + token}
params = {'type':'source'}
res = requests.get('https://api.github.com/orgs/CodingNinjasCodes/repos',headers = headers , params = params)
p = res.json()

for i in p:
    print(i.get('name'),i.get('watchers_count'),i.get('forks_count'))

# %%
#github create repo
#Create a new repository with the name 'DataScience API' in Github from Github API using OAuth(access token).
import requests
import json
token= '0e868abb4fd92c4d724f1f5be8a7fe0a3da43642'

# %%
#github organisation member
#Fetch all the members of the organisation 'CodingNinjasCodes' from Github API using OAuth(access token).
#Print the username of members present in organisation.
import requests
import json
token= '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'
headers={'Authorization':'token'+token} 

response = requests.get('https://api.github.com/orgs/CodingNinjasCodes/members',headers=headers) 
#print(response.url)
for i in response.json():
    print(i.get('login'))
# Out:
# https://api.github.com/orgs/CodingNinjasCodes/members
# aakash-cr7
# dakshkhetan
# ManishaKhattar
# namangupta01
# nidhiagarwal
# rohanraarora

# %%
#Fetch the list of contributors in the repository 'CodingNinjasCodes/JSNotes' in Github from Github API using OAuth(access token).
#Print the username of contributors and its number of commit done.
import requests
import json
token= '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'
headers={'Authorization':'token'+token} 
response = requests.get('https://api.github.com/repos/CodingNinjasCodes/JSNotes/stats/contributors',headers=headers) 
print(response.url)
for i in response.json():
    print(i.get('author').get('login'),i.get('total'))
# Out:
# https://api.github.com/repos/CodingNinjasCodes/JSNotes/stats/contributors
# Sherawat42 15
# tushartuteja 5
# Rawal27 13

# %%
#Github repo health
#Fetch the health percentage of repository 'CodingNinjasCodes/SmoothScrollJs' in Github from Github API using OAuth(access token).
#Print the health percentage of Repository as Integer Value.
#Note: Check the Github API documentation of Community Profile.
import requests
import json
token= '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'
headers={'Authorization':'token'+token} 
response = requests.get("https://api.github.com/repos/CodingNinjasCodes/SmoothScrollJs/community/profile", headers = headers)
print(response.json().get("health_percentage"))
# Out:
# 28

# %%
#github all repo
#Fetch the all repositories of organisation ‘fossasia’ from Github API using OAuth(access token)
#Print the name of repository.
import requests
import json
token= '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'
headers={'Authorization':'token'+token} 
for j in range(1,9):
    response = requests.get("https://api.github.com/orgs/fossasia/repos", headers=headers,params={"page":j})
    print(response.url)
    pData = response.json()
    for i in pData:
        print(i.get("name"))
# Out:
# https://api.github.com/orgs/fossasia/repos?page=1
# x-mario
# phimpme-android
# phimpme-drupal
# xmario_buildscript
# pslab-case
# meilix-systemlock
# fossasia10-drupal
# fossasia11-drupal
# blog.fossasia.org
# 2010.fossasia.org
# 2014.fossasia.org
# meilix
# phimpme-wordpress
# 2015.fossasia.org
# badge-magic-android
# api.fossasia.net
# directory.api.fossasia.net
# common.api.fossasia.net
# cmap.api.fossasia.net
# feed.api.freifunk.net
# feed.api.fossasia.net
# fossasia-communities
# sg18.sciencehack.asia
# gci14.fossasia.org
# fossasia-nodemailer
# 2011.fossasia.org
# 2012.fossasia.org
# labs.fossasia.org
# fossasia.net
# foss.vn
# https://api.github.com/orgs/fossasia/repos?page=2
# libregraphics.asia
# perspektive89.com
# susi_smart_box
# hotelxoai.com
# yaydoc-artwork
# fossasia-companion-android
# loklak_webclient
# circle-knitting
# open-event-attendee-android
# 2018.fossasia.org
# open-event
# open-event-droidgen
# open-event-wsgen
# open-event-server
# knitweb
# knitpat
# ...

# %%
#ta code
import requests
import json
data={'client_id':'e8b41835d5ceb11fd757','redirect_uri' : 'https://www.google.co.in/','scope':'repo', 'state':'random_123'}
r1 = requests.get('https://github.com/login/oauth/authorize' , data = data)
#print(r1.url)

#e416ce60162313310e09
info={'client_id': 'e8b41835d5ceb11fd757', 'client_secret':'8c728727fe64d970d261329db4b7b26319e425e1','redirect_uri':
     'https://www.google.co.in/', 'code':'e416ce60162313310e09','state':'random_123'}
r2 = requests.post('https://github.com/login/oauth/access_token', data=info)
#print(r2.text)

for j in range(1,9):
    h = {'Accept': 'application/vnd.github.nebula-preview+json', 'Authorization' : 'bearer abd652ab9f45274a70d1f201d45b97d8856740bb'}
    r3 = requests.get('https://api.github.com/orgs/fossasia/repos', headers = h,params={"page":j})
    python = r3.json()
#print(python)

    for i in python:
        print(i['name'])
# Out:
# x-mario
# phimpme-android
# phimpme-drupal
# xmario_buildscript
# pslab-case
# meilix-systemlock
# fossasia10-drupal
# fossasia11-drupal
# blog.fossasia.org
# 2010.fossasia.org
# 2014.fossasia.org
# meilix
# phimpme-wordpress
# 2015.fossasia.org
# badge-magic-android
# api.fossasia.net
# directory.api.fossasia.net
# common.api.fossasia.net
# cmap.api.fossasia.net
# feed.api.freifunk.net
# feed.api.fossasia.net
# fossasia-communities
# sg18.sciencehack.asia
# gci14.fossasia.org
# fossasia-nodemailer
# 2011.fossasia.org
# 2012.fossasia.org
# labs.fossasia.org
# fossasia.net
# foss.vn
# libregraphics.asia
# perspektive89.com
# susi_smart_box
# hotelxoai.com
# yaydoc-artwork
# fossasia-companion-android
# loklak_webclient
# circle-knitting
# open-event-attendee-android
# 2018.fossasia.org
# open-event
# open-event-droidgen
# open-event-wsgen
# open-event-server
# knitweb
# knitpat
# knitlib
# pslab-expeyes
# timeline.api.fossasia.net
# 2016.fossasia.org
# fossasia.org
# pslab-sister
# ...

# %%
#ta
in the first get
see the parameters

there is a parameter called page
where we specify which page to fetch results from

so by default it takes 1 if you don't specify any

so since here we needed to fetch the result for first 8 pages
so we ran a for loop

and every time we passed in the page number from 1 to 9
